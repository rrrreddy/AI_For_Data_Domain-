# %%
# %pip install python-dotenv
# %pip install google-genai
# Out:
# Requirement already satisfied: python-dotenv in /usr/local/python/3.12.1/lib/python3.12/site-packages (1.2.2)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting google-genai
#   Downloading google_genai-2.8.0-py3-none-any.whl.metadata (53 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /home/codespace/.local/lib/python3.12/site-packages (from google-genai) (4.12.1)
# Collecting google-auth<3.0.0,>=2.48.1 (from google-auth[requests]<3.0.0,>=2.48.1->google-genai)
#   Downloading google_auth-2.53.0-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /home/codespace/.local/lib/python3.12/site-packages (from google-genai) (0.28.1)
# Collecting pydantic<3.0.0,>=2.9.0 (from google-genai)
#   Downloading pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /home/codespace/.local/lib/python3.12/site-packages (from google-genai) (2.32.5)
# Collecting tenacity<9.2.0,>=8.2.3 (from google-genai)
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting websockets<17.0,>=13.0.0 (from google-genai)
#   Downloading websockets-16.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /home/codespace/.local/lib/python3.12/site-packages (from google-genai) (4.15.0)
# Collecting distro<2,>=1.7.0 (from google-genai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting sniffio (from google-genai)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: idna>=2.8 in /home/codespace/.local/lib/python3.12/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting cryptography>=38.0.3 (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai)
#   Downloading cryptography-48.0.0-cp311-abi3-manylinux_2_34_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.9.0->google-genai)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.4 (from pydantic<3.0.0,>=2.9.0->google-genai)
#   Downloading pydantic_core-2.46.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.9.0->google-genai)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.6.3)
# Requirement already satisfied: cffi>=2.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.0.0)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (3.0)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai)
#   Downloading pyasn1-0.6.3-py3-none-any.whl.metadata (8.4 kB)
# Downloading google_genai-2.8.0-py3-none-any.whl (832 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 832.5/832.5 kB 10.7 MB/s  0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading google_auth-2.53.0-py3-none-any.whl (246 kB)
# Downloading pydantic-2.13.4-py3-none-any.whl (472 kB)
# Downloading pydantic_core-2.46.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 16.6 MB/s  0:00:00
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading websockets-16.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (184 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading cryptography-48.0.0-cp311-abi3-manylinux_2_34_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 31.7 MB/s  0:00:00
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading pyasn1-0.6.3-py3-none-any.whl (83 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: websockets, typing-inspection, tenacity, sniffio, pydantic-core, pyasn1, distro, annotated-types, pydantic, pyasn1-modules, cryptography, google-auth, google-genai
#   WARNING: The script websockets is installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  5/13 [pyasn1]  WARNING: The script distro is installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13/13 [google-genai] [google-genai]s]
# Successfully installed annotated-types-0.7.0 cryptography-48.0.0 distro-1.9.0 google-auth-2.53.0 google-genai-2.8.0 pyasn1-0.6.3 pyasn1-modules-0.4.2 pydantic-2.13.4 pydantic-core-2.46.4 sniffio-1.3.1 tenacity-9.1.4 typing-inspection-0.4.2 websockets-16.0
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
import os
from google import genai

load_dotenv()

client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))

# 1. Initialize the client
# If you set the env var, you don't need to pass the key here
client = genai.Client(api_key=os.environ.get("GOOGLE_API_KEY"))

# 2. Generate text
response = client.models.generate_content(
    model="gemini-2.5-flash", 
    contents="Write a poem on my friend vikas reddy chennupalli."
)

print(f"Assistant: {response.text}")
# Out:
# Assistant: Here's a poem for your friend, Vikas Reddy Chennupalli!
#
# To Vikas Reddy Chennupalli, a name we know so well,
# A story of true friendship, with a special tale to tell.
# With a spirit bright and a heart so kind,
# A better friend, one could never find.
#
# Through thick and thin, your loyalty shines,
# A comfort in life's intricate designs.
# With laughter shared and wisdom too,
# There's always something good when we're with you.
#
# From challenges faced to victories won,
# Your steadfast presence outshines the sun.
# A beacon of hope, a guiding light,
# Making every moment feel just right.
#
# Your drive and passion, a sight to see,
# Inspiring all of us to truly be,
# The best versions of ourselves each day,
# Guiding us along the way.
#
# So here's to you, Vikas, a friend so true,
# May life bring all good things your way, in all you pursue.
# May joy and peace forever abound,
# The truest friendship, forever found.
